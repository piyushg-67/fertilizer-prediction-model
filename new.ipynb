# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Fertilizer Prediction.csv', encoding='unicode_escape')

# %%
df.head()
# Out:
#    Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           26         52        38     Sandy      Maize        37          0
# 1           29         52        45     Loamy  Sugarcane        12          0
# 2           34         65        62     Black     Cotton         7          9
# 3           32         62        34       Red    Tobacco        22          0
# 4           28         54        46    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
#creating a dictionary to map the numerical value into integer 
#and then remove the categorical value

soil_dict={'Loamy':1,
           'Sandy': 2,
           'Clayey':3,
           'Black':4,
           'Red':5
}

crop_dict= {'Sugarcane':1,
            'Cotton':2,
            'Millets':3,
            'Paddy':4,
            'Pulses':5,
            'Wheat':6,
            'Tobacco':7,
            'Barley':8,
            'Oil seeds':9,
            'Ground Nuts':10,
            'Maize':11

}

df['Soil Num']=df['Soil Type'].map(soil_dict)
df['Crop Num']=df['Crop Type'].map(crop_dict)

df=df.drop(['Soil Type', 'Crop Type'],axis=1)
df.head()
# Out:
#    Temparature  Humidity   Moisture  Nitrogen  Potassium  Phosphorous  \
# 0           26         52        38        37          0            0
# 1           29         52        45        12          0           36
# 2           34         65        62         7          9           30
# 3           32         62        34        22          0           20
# 4           28         54        46        35          0            0
#
#   Fertilizer Name  Soil Num  Crop Num
# 0            Urea         2        11
# 1             DAP         1         1
# 2        14-35-14         4         2
# 3           28-28         5         7
# 4            Urea         3         4

# %%
X=df.drop(["Fertilizer Name"],axis=1)
Y= df['Fertilizer Name']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
#Creating instances of Decision Tree Classifier for our model building
classifier=DecisionTreeClassifier()
classifier.fit(X_train,Y_train)
ypred=classifier.predict(X_test)
accuracy_score(Y_test,ypred)
# Out:
# 0.95

# %%
import tkinter as tk



def predict_button_clicked():
    # Get values from entry widgets
    temperature_value = float(temperature_entry.get())
    humidity_value = float(humidity_entry.get())
    moisture_value = float(moisture_entry.get())
    nitrogen_value = float(nitrogen_entry.get())
    potassium_value = float(potassium_entry.get())
    phosphorous_value = float(phosphorous_entry.get())
    soil_num_value = int(soil_num_entry.get())
    crop_num_value = int(crop_num_entry.get())

    # Call the predict_fertilizer function
    prediction_result = predict_fertilizer(
        Temperature=temperature_value,
        Humidity=humidity_value,
        Moisture=moisture_value,
        Nitrogen=nitrogen_value,
        Potassium=potassium_value,
        Phosphorous=phosphorous_value,
        Soil_Num=soil_num_value,
        Crop_Num=crop_num_value
    )

def predict_fertilizer(Temperature, Humidity, Moisture, Nitrogen, Potassium, Phosphorous, Soil_Num, Crop_Num):
    features = np.array([[Temperature, Humidity, Moisture, Nitrogen, Potassium, Phosphorous, Soil_Num, Crop_Num]])
    prediction = classifier.predict(features).reshape(1, -1)
    result_label.config(text=f"Predicted Fertilizer: {prediction[0]}")


# Create the main window
window = tk.Tk()
window.title("Fertilizer Prediction ")
window.geometry("300x250")

# Add components to the window
temperature_label = tk.Label(window, text="Temperature:")
temperature_label.grid(row=0, column=0, columnspan=1)

temperature_entry = tk.Entry(window)
temperature_entry.grid(row=0, column=1)

humidity_label = tk.Label(window, text="Humidity:")
humidity_label.grid(row=1, column=0, columnspan=1)

humidity_entry = tk.Entry(window)
humidity_entry.grid(row=1, column=1)

moisture_label = tk.Label(window, text="Moisture:")
moisture_label.grid(row=2, column=0, columnspan=1)

moisture_entry = tk.Entry(window)
moisture_entry.grid(row=2, column=1)

nitrogen_label = tk.Label(window, text="Nitrogen:")
nitrogen_label.grid(row=3, column=0, columnspan=1)

nitrogen_entry = tk.Entry(window)
nitrogen_entry.grid(row=3, column=1)

potassium_label = tk.Label(window, text="Potassium:")
potassium_label.grid(row=4, column=0, columnspan=1)

potassium_entry = tk.Entry(window)
potassium_entry.grid(row=4, column=1)

phosphorous_label = tk.Label(window, text="Phosphorous:")
phosphorous_label.grid(row=5, column=0, columnspan=1)

phosphorous_entry = tk.Entry(window)
phosphorous_entry.grid(row=5, column=1)

soil_num_label = tk.Label(window, text="Soil Number:")
soil_num_label.grid(row=6, column=0, columnspan=1)

soil_num_entry = tk.Entry(window)
soil_num_entry.grid(row=6, column=1)

crop_num_label = tk.Label(window, text="Crop Number:")
crop_num_label.grid(row=7, column=0, columnspan=1)

crop_num_entry = tk.Entry(window)
crop_num_entry.grid(row=7, column=1)

predict_button = tk.Button(window, text="Predict Fertilizer", command=predict_button_clicked)
predict_button.grid(row=8, column=0, columnspan=2,pady=5)

result_label = tk.Label(window, text="Predicted Fertilizer: ")
result_label.grid(row=9, column=0, columnspan=2,pady=5)

# Start the Tkinter event loop
window.mainloop()
